# %%
# !pip install -qU transformers accelerate bitsandbytes
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 15.0 MB/s eta 0:00:00

# %%
import transformers
transformers.__version__
# Out:
# '4.57.3'

# %%
from transformers import BitsAndBytesConfig
import torch

bnb_config = BitsAndBytesConfig(
    load_in_4bit = True,
    bnb_4bit_quanty_type = "nf4",
    bnb_4bit_use_double_quanty = True,
    bnb_4bit_compute_dtype=torch.bfloat16,
)

# %%
from transformers import AutoTokenizer
import torch

# Huggingface model path
model_name = "mistralai/Mistral-7B-v0.1"

tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/996 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
from transformers import AutoModelForCausalLM

model= AutoModelForCausalLM.from_pretrained(
  model_name,
  device_map="auto",
  quantization_config=bnb_config,
  dtype="auto",
)
# Out:
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]

# %%
from transformers import pipeline

pipe = pipeline(
    "text-generation",
    model = model,
    tokenizer = tokenizer,
    torch_dtype=torch.bfloat16,
    device_map = "auto"
)
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Device set to use cuda:0

# %%
prompt = "As a data scientist, what is overfitting?"

# %%
sequence = pipe(
    prompt,
    do_sample = True,
    max_new_tokens = 100,
    temperature = 0.6,
    top_k = 50,
    top_p = 0.95,
    num_return_sequences = 1,
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.

# %%
print(sequence[0]["generated_text"])
# Out:
# As a data scientist, what is overfitting? And how can you avoid it?
#
# Overfitting is a common issue in machine learning that occurs when a model is trained on a specific set of data that it then cannot generalize to other data.
#
# ## What is Overfitting in Machine Learning?
#
# Overfitting is a common problem in machine learning. It occurs when a model is trained on a specific set of data that it then cannot generalize to other data.
#
# This can happen for a number of reasons

# %%
prompt = "As a data scientist, what is overfitting?"

sequence = pipe(
    prompt,
    do_sample = True,
    max_new_tokens = 100,
    temperature = 0.8,
    top_k = 50,
    top_p = 0.95,
    num_return_sequences = 1,
)

print(sequence[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# As a data scientist, what is overfitting?
#
# ### Overfitting
#
# A. A data scientist who uses the same model to train and test datasets.
# B. A data scientist who uses a model that is too complex.
# C. A data scientist who uses a model that is too simple.
# D. A data scientist who uses a model that is too large.
#
# ### Correct!
#
# #### Wrong!
#
# A data scientist who uses the same model to train and test datasets.
#
# An

# %%
prompt = "As an NLP engineer, how to learn NLP in 5 steps?"

sequence = pipe(
    prompt,
    do_sample = True,
    max_new_tokens = 300,
    temperature = 0.8,
    top_k = 50,
    top_p = 0.95,
    num_return_sequences = 1,
)

print(sequence[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# As an NLP engineer, how to learn NLP in 5 steps?
#
# Step 1:
#
# Get the best NLP tools like huggingface and fastai
#
# Step 2:
#
# Get the best NLP datasets like common voice, opencorpora, and nltk
#
# Step 3:
#
# Understand the NLP architecture from the paper Transformer
#
# Step 4:
#
# Understand the NLP architecture from the paper BERT
#
# Step 5:
#
# Use BERT to solve NLP problems
#
# Step 6:
#
# Train your own BERT and fine-tune it to solve your own problems
#
# Step 7:
#
# If you don't get the problem solved, you can change the problem to a problem that can be solved by BERT.
#
# Step 8:
#
# Repeat the above steps
#
# Step 9:
#
# Repeat the above steps
#
# Step 10:
#
# Repeat the above steps
#
# Step 11:
#
# Repeat the above steps
#
# Step 12:
#
# Repeat the above steps
#
# Step 13:
#
# Repeat the above steps
#
# Step 14:
#
# Repeat the above steps
#
# Step 15:
#
# Repeat the above steps
#
# Step 16:
#
# Repeat the above steps
#
# Step 17:
#
# Repeat the above steps

# %%
prompt = "Türkiye'nin başkenti neresidir?"

sequence = pipe(
    prompt,
    do_sample = True,
    max_new_tokens = 300,
    temperature = 1,
    top_k = 50,
    top_p = 0.95,
    num_return_sequences = 1,
)

print(sequence[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Türkiye'nin başkenti neresidir? What is Turkey’s capital? How many times was Istanbul the capital of an empire? These are some of the topics covered in this lesson. If you do not know the answers, please learn them now.
#
# A new capital of the Ottoman empire was chosen in 1923 and it is now Türkiye'nin başkenti neresidir? The capital of the Ottoman empire is now Edirne. What was it before this and what is Istanbul's relationship to Edirne? How many times did Istanbul serve as the capital of an empire?
#
# When I read about these topics, I realized that I didn’t know the answers. When I did research on these topics, I learned many interesting facts. I hope the same information will be as interesting for you. Here they are:
#
# Türkiye'nin başkenti neresidir?
#
# Istanbul is now Türkiye'nin başkenti neresidir? The capital of Türkiye. Before that, it was known as Istanbul. Istanbul has served as the capital of many empires. After the Ottoman, Roman and Byzantine Empire, it is the fourth capital of Istanbul. What other empire did Istanbul serve as the capital?
#
# How many times was Istanbul the capital of an empire
